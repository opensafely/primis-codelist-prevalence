# %% [markdown]
# # Comparing prevalence of PRIMIS codelists

# %%
import pandas as pd
import numpy as np
import os
from IPython.display import display, Markdown

# %% [markdown]
# ### Load data

# %%
# load data (note multi-level columnns)
df_e = pd.read_csv(os.path.join("..","released-outputs","code-prevalence-by-age-and-sex_emis.csv"), header=[0,1])
df_t = pd.read_csv(os.path.join("..","released-outputs","code-prevalence-by-age-and-sex_tpp.csv"), header=[0,1])

# rename some column headers
df_e = df_e.rename(columns={'Unnamed: 7_level_1': '', "ageband":'codelist', "sex":''})
df_t = df_t.rename(columns={'Unnamed: 7_level_1': '', "ageband":'codelist', "sex":''})

# set index
df_e = df_e.set_index(("codelist"))
df_t = df_t.set_index(("codelist"))

# %%
# define order in which to look at the codelist (by type)
output_order = ['total_population', 
              'eth2001', 'non_eth2001', 'eth_norecord', 'eth_notgiptref','eth_notstated', 
              'longres', 
              'carehome', 'nursehome', 'domcare', 
              'carer', 'notcarer', 'hhld_imdef', 
              'shield', 'nonshield',
              'ast', 'astadm', 'astrx', 
              'bmi', 'bmi_stage', 'sev_obesity',
              'ckd15', 'ckd35', 'ckd_cov', 
              'immdx_cov', 'immrx', 
              'diab', 'dmres',
              'chd_cov', 'resp_cov', 'cld', 
              'cns_cov','spln_cov',
              'sev_mental', 'smhres', 'learndis',
              'preg', 'pregdel',               
              'cov1decl', 'cov2decl', 'covadm1', 'covadm2', 'covcontra', 'covrx',
       ]

# define display headers for each group
headers = {'total_population': 'Total population', 'eth2001': 'Ethnicity',  'longres': 'Care home resident',
  'carehome': 'Care staff',  'carer': 'Carer / household',
  'shield': 'Shielding',  'ast': 'Asthma',
  'bmi': 'BMI',  'ckd15': 'CKD',
  'immdx_cov': 'Immunodeficiency',   'diab': 'Diabetes',
  'chd_cov': ' Heart/lung conditions',
  'cns_cov':'Other conditions', 
  'preg': 'Pregnancy/delivery',              
  'sev_mental': 'MH / LD',   'cov1decl': 'Covid vax'}

# %%
for i in output_order:
    if i in headers:
        display(Markdown(f"## \n ## {headers[i]}"))
        
    # find relevant row of each dataframe and rename with suffix
    t = df_t.loc[i].rename(i+" (tpp)")
    e = df_e.loc[i].rename(i+" (emis)")
    
    # concatenate into one table
    out = pd.concat([e,t], axis=1)
    
    # calculate difference in rates
    out["diff (e - t)"] = out[i+" (emis)"] - out[i+" (tpp)"]
    out["diff (% of t)"] = round((100*out["diff (e - t)"]/out[i+" (tpp)"]),1).fillna(0)
    
    display(out)
# Out:
# ##
#  ## Total population
#          total_population (emis)  total_population (tpp)  diff (e - t)  \
# 16-39 F                5255733.0               3656638.0     1599095.0
#       M                5331096.0               3730219.0     1600877.0
# 40-69 F                6048159.0               4432633.0     1615526.0
#       M                6272607.0               4573967.0     1698640.0
# 70+   F                2432884.0               1896911.0      535973.0
#       M                2013750.0               1578149.0      435601.0
# total                 27354229.0              19868517.0     7485712.0
#
#          diff (% of t)
# 16-39 F           43.7
#       M           42.9
# 40-69 F           36.4
#       M           37.1
# 70+   F           28.3
#       M           27.6
# total             37.7
# ##
#  ## Ethnicity
#          eth2001 (emis)  eth2001 (tpp)  diff (e - t)  diff (% of t)
# 16-39 F           701.1          605.7          95.4           15.8
#       M           628.5          540.9          87.6           16.2
# 40-69 F           749.2          648.0         101.2           15.6
#       M           700.8          611.2          89.6           14.7
# 70+   F           733.1          592.7         140.4           23.7
#       M           730.1          586.9         143.2           24.4
# total             702.5          601.5         101.0           16.8
#          non_eth2001 (emis)  non_eth2001 (tpp)  diff (e - t)  diff (% of t)
# 16-39 F               245.6              351.9        -106.3          -30.2
#       M               217.5              308.1         -90.6          -29.4
# 40-69 F               315.7              389.7         -74.0          -19.0
#       M               289.5              367.1         -77.6          -21.1
# 70+   F               327.2              379.4         -52.2          -13.8
#       M               324.5              378.9         -54.4          -14.4
# total                 278.8              360.4         -81.6          -22.6
#          eth_norecord (emis)  eth_norecord (tpp)  diff (e - t)  diff (% of t)
# 16-39 F                  5.2                 5.8          -0.6          -10.3
#       M                  5.5                 5.6          -0.1           -1.8
# 40-69 F                  6.1                 6.1           0.0            0.0
#       M                  6.4                 6.0           0.4            6.7
# 70+   F                  5.7                 5.7           0.0            0.0
#       M                  5.8                 5.2           0.6           11.5
# total                    5.8                 5.8           0.0            0.0
#          eth_notgiptref (emis)  eth_notgiptref (tpp)  diff (e - t)  \
# 16-39 F                    0.0                   0.0           0.0
#       M                    0.0                   0.0           0.0
# 40-69 F                    0.0                   0.0           0.0
#       M                    0.0                   0.0           0.0
# 70+   F                    0.0                   0.0           0.0
#       M                    0.0                   0.0           0.0
# total                      0.0                   0.0           0.0
#
#          diff (% of t)
# 16-39 F            0.0
#       M            0.0
# 40-69 F            0.0
#       M            0.0
# 70+   F            0.0
#       M            0.0
# total              0.0
#          eth_notstated (emis)  eth_notstated (tpp)  diff (e - t)  \
# 16-39 F                  29.7                 45.3         -15.6
#       M                  28.9                 46.6         -17.7
# 40-69 F                  18.4                 48.4         -30.0
#       M                  20.1                 49.6         -29.5
# 70+   F                  16.0                 49.5         -33.5
#       M                  15.6                 49.4         -33.8
# total                    22.6                 47.9         -25.3
#
#          diff (% of t)
# 16-39 F          -34.4
#       M          -38.0
# 40-69 F          -62.0
#       M          -59.5
# 70+   F          -67.7
#       M          -68.4
# total            -52.8
# ##
#  ## Care home resident
#          longres (emis)  longres (tpp)  diff (e - t)  diff (% of t)
# 16-39 F             0.6            0.9          -0.3          -33.3
#       M             1.0            1.6          -0.6          -37.5
# 40-69 F             2.0            2.5          -0.5          -20.0
#       M             2.7            3.3          -0.6          -18.2
# 70+   F            43.2           49.2          -6.0          -12.2
#       M            22.8           25.9          -3.1          -12.0
# total               6.9            8.5          -1.6          -18.8
# ##
#  ## Care staff
#          carehome (emis)  carehome (tpp)  diff (e - t)  diff (% of t)
# 16-39 F              0.3             0.8          -0.5          -62.5
#       M              0.1             0.1           0.0            0.0
# 40-69 F              0.6             1.4          -0.8          -57.1
#       M              0.1             0.2          -0.1          -50.0
# 70+   F              0.2             0.2           0.0            0.0
#       M              0.0             0.1          -0.1         -100.0
# total                0.2             0.6          -0.4          -66.7
#          nursehome (emis)  nursehome (tpp)  diff (e - t)  diff (% of t)
# 16-39 F               0.1              0.2          -0.1          -50.0
#       M               0.0              0.0           0.0            0.0
# 40-69 F               0.1              0.3          -0.2          -66.7
#       M               0.0              0.0           0.0            0.0
# 70+   F               0.0              0.0           0.0            0.0
#       M               0.0              0.0           0.0            0.0
# total                 0.0              0.1          -0.1         -100.0
#          domcare (emis)  domcare (tpp)  diff (e - t)  diff (% of t)
# 16-39 F             0.2            0.6          -0.4          -66.7
#       M             0.0            0.1          -0.1         -100.0
# 40-69 F             0.4            1.3          -0.9          -69.2
#       M             0.1            0.2          -0.1          -50.0
# 70+   F             0.0            0.1          -0.1         -100.0
#       M             0.0            0.1          -0.1         -100.0
# total               0.2            0.5          -0.3          -60.0
# ##
#  ## Carer / household
#          carer (emis)  carer (tpp)  diff (e - t)  diff (% of t)
# 16-39 F          18.6         14.8           3.8           25.7
#       M           6.6          5.9           0.7           11.9
# 40-69 F          64.0         57.4           6.6           11.5
#       M          25.9         23.5           2.4           10.2
# 70+   F          82.7         84.3          -1.6           -1.9
#       M          55.9         57.3          -1.4           -2.4
# total            36.4         34.7           1.7            4.9
#          notcarer (emis)  notcarer (tpp)  diff (e - t)  diff (% of t)
# 16-39 F             48.1            16.6          31.5          189.8
#       M             32.1            11.5          20.6          179.1
# 40-69 F             47.4            19.1          28.3          148.2
#       M             39.4            14.1          25.3          179.4
# 70+   F             61.6            33.0          28.6           86.7
#       M             53.6            23.2          30.4          131.0
# total               44.4            17.8          26.6          149.4
#          hhld_imdef (emis)  hhld_imdef (tpp)  diff (e - t)  diff (% of t)
# 16-39 F                0.2               0.5          -0.3          -60.0
#       M                0.2               0.5          -0.3          -60.0
# 40-69 F                0.2               0.7          -0.5          -71.4
#       M                0.2               0.6          -0.4          -66.7
# 70+   F                0.1               0.2          -0.1          -50.0
#       M                0.1               0.2          -0.1          -50.0
# total                  0.2               0.5          -0.3          -60.0
# ##
#  ## Shielding
#          shield (emis)  shield (tpp)  diff (e - t)  diff (% of t)
# 16-39 F           15.3          36.9         -21.6          -58.5
#       M           11.4          19.8          -8.4          -42.4
# 40-69 F           53.0          82.0         -29.0          -35.4
#       M           43.8          67.8         -24.0          -35.4
# 70+   F          124.9         136.9         -12.0           -8.8
#       M          142.8         155.9         -13.1           -8.4
# total             48.5          69.9         -21.4          -30.6
#          nonshield (emis)  nonshield (tpp)  diff (e - t)  diff (% of t)
# 16-39 F              11.3             19.5          -8.2          -42.1
#       M               8.4             11.1          -2.7          -24.3
# 40-69 F              18.3             31.8         -13.5          -42.5
#       M              14.7             27.2         -12.5          -46.0
# 70+   F              29.8             55.0         -25.2          -45.8
#       M              30.0             57.0         -27.0          -47.4
# total                16.1             28.8         -12.7          -44.1
# ##
#  ## Asthma
#          ast (emis)  ast (tpp)  diff (e - t)  diff (% of t)
# 16-39 F       143.4      155.8         -12.4           -8.0
#       M       159.1      167.3          -8.2           -4.9
# 40-69 F       149.1      153.2          -4.1           -2.7
#       M       118.9      121.6          -2.7           -2.2
# 70+   F       140.4      134.5           5.9            4.4
#       M       107.9      104.6           3.3            3.2
# total         139.2      143.4          -4.2           -2.9
#          astadm (emis)  astadm (tpp)  diff (e - t)  diff (% of t)
# 16-39 F            4.6           4.1           0.5           12.2
#       M            4.9           4.8           0.1            2.1
# 40-69 F            5.9           4.8           1.1           22.9
#       M            3.5           3.1           0.4           12.9
# 70+   F            6.2           4.8           1.4           29.2
#       M            4.1           3.2           0.9           28.1
# total              4.8           4.2           0.6           14.3
#          astrx (emis)  astrx (tpp)  diff (e - t)  diff (% of t)
# 16-39 F          98.0        101.7          -3.7           -3.6
#       M          86.0         77.7           8.3           10.7
# 40-69 F         199.5        214.3         -14.8           -6.9
#       M         132.1        142.7         -10.6           -7.4
# 70+   F         309.8        317.5          -7.7           -2.4
#       M         265.2        272.5          -7.3           -2.7
# total           157.1        165.9          -8.8           -5.3
# ##
#  ## BMI
#          bmi (emis)  bmi (tpp)  diff (e - t)  diff (% of t)
# 16-39 F       812.3      844.1         -31.8           -3.8
#       M       623.6      652.4         -28.8           -4.4
# 40-69 F       945.2      953.8          -8.6           -0.9
#       M       886.5      894.6          -8.1           -0.9
# 70+   F       960.0      969.8          -9.8           -1.0
#       M       958.6      965.9          -7.3           -0.8
# total         845.8      865.9         -20.1           -2.3
#          bmi_stage (emis)  bmi_stage (tpp)  diff (e - t)  diff (% of t)
# 16-39 F              48.5             62.7         -14.2          -22.6
#       M              27.3             35.5          -8.2          -23.1
# 40-69 F             139.1            184.7         -45.6          -24.7
#       M             102.6            148.2         -45.6          -30.8
# 70+   F             164.4            220.9         -56.5          -25.6
#       M             157.3            220.0         -62.7          -28.5
# total                95.1            132.1         -37.0          -28.0
#          sev_obesity (emis)  sev_obesity (tpp)  diff (e - t)  diff (% of t)
# 16-39 F                 4.5                5.6          -1.1          -19.6
#       M                 1.4                1.7          -0.3          -17.6
# 40-69 F                11.8               14.3          -2.5          -17.5
#       M                 5.5                7.2          -1.7          -23.6
# 70+   F                 7.9                9.4          -1.5          -16.0
#       M                 4.8                5.9          -1.1          -18.6
# total                   6.1                7.6          -1.5          -19.7
# ##
#  ## CKD
#          ckd15 (emis)  ckd15 (tpp)  diff (e - t)  diff (% of t)
# 16-39 F           1.8          2.0          -0.2          -10.0
#       M           1.5          1.6          -0.1           -6.3
# 40-69 F          28.2         27.5           0.7            2.5
#       M          23.5         22.2           1.3            5.9
# 70+   F         234.3        232.1           2.2            0.9
#       M         201.7        197.0           4.7            2.4
# total            47.9         49.7          -1.8           -3.6
#          ckd35 (emis)  ckd35 (tpp)  diff (e - t)  diff (% of t)
# 16-39 F           0.8          0.8           0.0            0.0
#       M           0.8          0.7           0.1           14.3
# 40-69 F          21.9         20.9           1.0            4.8
#       M          17.5         16.1           1.4            8.7
# 70+   F         221.0        218.6           2.4            1.1
#       M         186.4        181.5           4.9            2.7
# total            42.5         43.9          -1.4           -3.2
#          ckd_cov (emis)  ckd_cov (tpp)  diff (e - t)  diff (% of t)
# 16-39 F             1.4            1.5          -0.1           -6.7
#       M             1.8            1.8           0.0            0.0
# 40-69 F             4.1            3.8           0.3            7.9
#       M             5.0            4.7           0.3            6.4
# 70+   F            14.1           12.9           1.2            9.3
#       M            16.5           14.9           1.6           10.7
# total               5.1            4.9           0.2            4.1
# ##
#  ## Immunodeficiency
#          immdx_cov (emis)  immdx_cov (tpp)  diff (e - t)  diff (% of t)
# 16-39 F               4.2              4.4          -0.2           -4.5
#       M               4.6              4.6           0.0            0.0
# 40-69 F              13.1             12.9           0.2            1.6
#       M              14.1             13.2           0.9            6.8
# 70+   F              26.4             26.8          -0.4           -1.5
#       M              32.5             32.3           0.2            0.6
# total                12.6             12.7          -0.1           -0.8
#          immrx (emis)  immrx (tpp)  diff (e - t)  diff (% of t)
# 16-39 F           8.5          7.8           0.7            9.0
#       M           7.1          6.2           0.9           14.5
# 40-69 F          26.0         24.5           1.5            6.1
#       M          17.8         16.5           1.3            7.9
# 70+   F          37.8         35.6           2.2            6.2
#       M          30.1         27.5           2.6            9.5
# total            18.4         17.5           0.9            5.1
# ##
#  ## Diabetes
#          diab (emis)  diab (tpp)  diff (e - t)  diff (% of t)
# 16-39 F         26.5        27.9          -1.4           -5.0
#       M         10.5        11.1          -0.6           -5.4
# 40-69 F         82.8        80.8           2.0            2.5
#       M         98.5        98.3           0.2            0.2
# 70+   F        167.2       164.4           2.8            1.7
#       M        225.2       223.0           2.2            1.0
# total           79.5        81.3          -1.8           -2.2
#          dmres (emis)  dmres (tpp)  diff (e - t)  diff (% of t)
# 16-39 F           0.3          0.5          -0.2          -40.0
#       M           0.1          0.2          -0.1          -50.0
# 40-69 F           1.6          2.1          -0.5          -23.8
#       M           1.8          1.8           0.0            0.0
# 70+   F           4.9          5.0          -0.1           -2.0
#       M           6.0          5.9           0.1            1.7
# total             1.7          1.9          -0.2          -10.5
# ##
#  ##  Heart/lung conditions
#          chd_cov (emis)  chd_cov (tpp)  diff (e - t)  diff (% of t)
# 16-39 F            11.1           12.4          -1.3          -10.5
#       M             8.3            8.9          -0.6           -6.7
# 40-69 F            62.5           63.3          -0.8           -1.3
#       M            87.2           91.2          -4.0           -4.4
# 70+   F           283.5          284.7          -1.2           -0.4
#       M           385.9          388.9          -3.0           -0.8
# total              91.2           97.2          -6.0           -6.2
#          resp_cov (emis)  resp_cov (tpp)  diff (e - t)  diff (% of t)
# 16-39 F              2.5             2.5           0.0            0.0
#       M              2.6             2.7          -0.1           -3.7
# 40-69 F             28.2            29.1          -0.9           -3.1
#       M             27.7            28.4          -0.7           -2.5
# 70+   F             99.1            97.9           1.2            1.2
#       M            122.6           123.1          -0.5           -0.4
# total               31.4            33.1          -1.7           -5.1
#          cld (emis)  cld (tpp)  diff (e - t)  diff (% of t)
# 16-39 F         5.2        5.7          -0.5           -8.8
#       M         6.8        7.9          -1.1          -13.9
# 40-69 F        23.6       24.9          -1.3           -5.2
#       M        29.6       31.1          -1.5           -4.8
# 70+   F        23.3       24.3          -1.0           -4.1
#       M        27.1       26.7           0.4            1.5
# total          18.4       19.7          -1.3           -6.6
# ##
#  ## Other conditions
#          cns_cov (emis)  cns_cov (tpp)  diff (e - t)  diff (% of t)
# 16-39 F            17.8           19.0          -1.2           -6.3
#       M            19.2           20.0          -0.8           -4.0
# 40-69 F            39.3           40.5          -1.2           -3.0
#       M            39.3           41.4          -2.1           -5.1
# 70+   F           132.3          140.1          -7.8           -5.6
#       M           141.7          147.2          -5.5           -3.7
# total              47.1           50.9          -3.8           -7.5
#          spln_cov (emis)  spln_cov (tpp)  diff (e - t)  diff (% of t)
# 16-39 F              5.2             5.8          -0.6          -10.3
#       M              2.8             2.8           0.0            0.0
# 40-69 F              7.4             8.0          -0.6           -7.5
#       M              4.8             5.1          -0.3           -5.9
# 70+   F              8.8             9.3          -0.5           -5.4
#       M              7.3             7.7          -0.4           -5.2
# total                5.6             6.1          -0.5           -8.2
# ##
#  ## MH / LD
#          sev_mental (emis)  sev_mental (tpp)  diff (e - t)  diff (% of t)
# 16-39 F                7.2               7.3          -0.1           -1.4
#       M                9.3               9.0           0.3            3.3
# 40-69 F               15.0              14.7           0.3            2.0
#       M               16.1              15.4           0.7            4.5
# 70+   F               14.8              13.6           1.2            8.8
#       M               10.3               9.5           0.8            8.4
# total                 12.3              11.9           0.4            3.4
#          smhres (emis)  smhres (tpp)  diff (e - t)  diff (% of t)
# 16-39 F            0.7           1.3          -0.6          -46.2
#       M            0.8           1.6          -0.8          -50.0
# 40-69 F            2.0           3.9          -1.9          -48.7
#       M            2.1           4.1          -2.0          -48.8
# 70+   F            2.2           4.4          -2.2          -50.0
#       M            1.7           3.3          -1.6          -48.5
# total              1.5           3.0          -1.5          -50.0
#          learndis (emis)  learndis (tpp)  diff (e - t)  diff (% of t)
# 16-39 F              5.3             6.4          -1.1          -17.2
#       M              9.2            10.7          -1.5          -14.0
# 40-69 F              4.4             4.7          -0.3           -6.4
#       M              5.5             6.0          -0.5           -8.3
# 70+   F              1.8             1.7           0.1            5.9
#       M              2.4             2.2           0.2            9.1
# total                5.4             6.0          -0.6          -10.0
# ##
#  ## Pregnancy/delivery
#          preg (emis)  preg (tpp)  diff (e - t)  diff (% of t)
# 16-39 F         76.9        73.7           3.2            4.3
#       M          0.0         0.1          -0.1         -100.0
# 40-69 F          5.8         4.4           1.4           31.8
#       M          0.0         0.2          -0.2         -100.0
# 70+   F          0.1         0.4          -0.3          -75.0
#       M          0.0         0.3          -0.3         -100.0
# total           16.1        14.7           1.4            9.5
#          pregdel (emis)  pregdel (tpp)  diff (e - t)  diff (% of t)
# 16-39 F            95.8           96.0          -0.2           -0.2
#       M             0.1            0.2          -0.1          -50.0
# 40-69 F             7.9            6.1           1.8           29.5
#       M             0.1            0.3          -0.2          -66.7
# 70+   F             0.1            0.5          -0.4          -80.0
#       M             0.1            0.3          -0.2          -66.7
# total              20.2           19.2           1.0            5.2
# ##
#  ## Covid vax
#          cov1decl (emis)  cov1decl (tpp)  diff (e - t)  diff (% of t)
# 16-39 F              0.0             1.2          -1.2         -100.0
#       M              0.0             0.9          -0.9         -100.0
# 40-69 F              0.0             3.6          -3.6         -100.0
#       M              0.0             3.1          -3.1         -100.0
# 70+   F              0.0            21.8         -21.8         -100.0
#       M              0.0            17.9         -17.9         -100.0
# total                0.0             5.4          -5.4         -100.0
#          cov2decl (emis)  cov2decl (tpp)  diff (e - t)  diff (% of t)
# 16-39 F              0.0             0.9          -0.9         -100.0
#       M              0.0             0.6          -0.6         -100.0
# 40-69 F              0.0             2.5          -2.5         -100.0
#       M              0.0             2.1          -2.1         -100.0
# 70+   F              0.0            16.5         -16.5         -100.0
#       M              0.0            13.2         -13.2         -100.0
# total                0.0             4.0          -4.0         -100.0
#          covadm1 (emis)  covadm1 (tpp)  diff (e - t)  diff (% of t)
# 16-39 F             0.0          108.3        -108.3         -100.0
#       M             0.0           43.6         -43.6         -100.0
# 40-69 F             0.0          274.1        -274.1         -100.0
#       M             0.0          172.0        -172.0         -100.0
# 70+   F             0.0          871.1        -871.1         -100.0
#       M             0.0          865.2        -865.2         -100.0
# total               0.0          280.7        -280.7         -100.0
#          covadm2 (emis)  covadm2 (tpp)  diff (e - t)  diff (% of t)
# 16-39 F             0.0          108.3        -108.3         -100.0
#       M             0.0           43.6         -43.6         -100.0
# 40-69 F             0.0          274.2        -274.2         -100.0
#       M             0.0          172.0        -172.0         -100.0
# 70+   F             0.0          871.3        -871.3         -100.0
#       M             0.0          865.5        -865.5         -100.0
# total               0.0          280.8        -280.8         -100.0
#          covcontra (emis)  covcontra (tpp)  diff (e - t)  diff (% of t)
# 16-39 F               0.0              0.0           0.0            0.0
#       M               0.0              0.0           0.0            0.0
# 40-69 F               0.0              0.0           0.0            0.0
#       M               0.0              0.0           0.0            0.0
# 70+   F               0.0              0.0           0.0            0.0
#       M               0.0              0.0           0.0            0.0
# total                 0.0              0.0           0.0            0.0
#          covrx (emis)  covrx (tpp)  diff (e - t)  diff (% of t)
# 16-39 F          91.4        108.3         -16.9          -15.6
#       M          39.2         43.7          -4.5          -10.3
# 40-69 F         254.2        274.1         -19.9           -7.3
#       M         162.7        172.0          -9.3           -5.4
# 70+   F         837.8        871.2         -33.4           -3.8
#       M         834.1        865.4         -31.3           -3.6
# total           254.6        280.8         -26.2           -9.3
