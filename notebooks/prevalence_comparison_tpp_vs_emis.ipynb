# %% [markdown]
# # Comparing prevalence of PRIMIS codelists

# %%
import pandas as pd
import numpy as np
import os
from IPython.display import display, Markdown

# %% [markdown]
# ### Load data

# %%
# load data (note multi-level columnns)
df_e = pd.read_csv(os.path.join("..","released-outputs","code-prevalence-by-age-and-sex_emis.csv"), header=[0,1])
df_t = pd.read_csv(os.path.join("..","released-outputs","code-prevalence-by-age-and-sex_tpp.csv"), header=[0,1])

# rename some column headers
df_e = df_e.rename(columns={'Unnamed: 7_level_1': '', "ageband":'codelist', "sex":''})
df_t = df_t.rename(columns={'Unnamed: 7_level_1': '', "ageband":'codelist', "sex":''})

# set index
df_e = df_e.set_index(("codelist"))
df_t = df_t.set_index(("codelist"))

# %%
# define order in which to look at the codelist (by type)
output_order = ['total_population', 
              'eth2001', 'non_eth2001', 'eth_norecord', 'eth_notgiptref','eth_notstated', 
              'longres', 
              'carehome', 'nursehome', 'domcare', 
              'carer', 'notcarer', 'hhld_imdef', 
              'shield', 'nonshield',
              'ast', 'astadm', 'astrx', 
              'bmi', 'bmi_stage', 'sev_obesity',
              'ckd15', 'ckd35', 'ckd_cov', 
              'immdx_cov', 'immrx', 
              'diab', 'dmres',
              'chd_cov', 'resp_cov', 'cld', 
              'cns_cov','spln_cov',
              'sev_mental', 'smhres', 'learndis',
              'preg', 'pregdel',               
              'cov1decl', 'cov2decl', 'covadm1', 'covadm2', 'covcontra', 'covrx',
       ]

# define display headers for each group
headers = {'total_population': 'Total population', 'eth2001': 'Ethnicity',  'longres': 'Care home resident',
  'carehome': 'Care staff',  'carer': 'Carer / household',
  'shield': 'Shielding',  'ast': 'Asthma',
  'bmi': 'BMI',  'ckd15': 'CKD',
  'immdx_cov': 'Immunodeficiency',   'diab': 'Diabetes',
  'chd_cov': ' Heart/lung conditions',
  'cns_cov':'Other conditions', 
  'preg': 'Pregnancy/delivery',              
  'sev_mental': 'MH / LD',   'cov1decl': 'Covid vax'}

# %%
for i in output_order:
    if i in headers:
        display(Markdown(f"## \n ## {headers[i]}"))
        
    # find relevant row of each dataframe and rename with suffix
    t = df_t.loc[i].rename(i+" (tpp)")
    e = df_e.loc[i].rename(i+" (emis)")
    
    # concatenate into one table
    out = pd.concat([e,t], axis=1)
    
    # calculate difference in rates
    out["diff (e - t)"] = out[i+" (emis)"] - out[i+" (tpp)"]
    out["diff (% of t)"] = round((100*out["diff (e - t)"]/out[i+" (tpp)"]),1).fillna(0)
    
    display(out)
# Out:
# ##
#  ## Total population
#          total_population (emis)  total_population (tpp)  diff (e - t)  \
# 16-39 F                5204929.0               3660005.0     1544924.0
#       M                5286628.0               3733826.0     1552802.0
# 40-69 F                5995889.0               4437189.0     1558700.0
#       M                6216444.0               4578857.0     1637587.0
# 70+   F                2404071.0               1898302.0      505769.0
#       M                1989604.0               1579304.0      410300.0
# total                 27097565.0              19887483.0     7210082.0
#
#          diff (% of t)
# 16-39 F           42.2
#       M           41.6
# 40-69 F           35.1
#       M           35.8
# 70+   F           26.6
#       M           26.0
# total             36.3
# ##
#  ## Ethnicity
#          eth2001 (emis)  eth2001 (tpp)  diff (e - t)  diff (% of t)
# 16-39 F           703.9          606.5          97.4           16.1
#       M           631.3          541.8          89.5           16.5
# 40-69 F           751.0          648.5         102.5           15.8
#       M           702.8          611.9          90.9           14.9
# 70+   F           734.3          593.2         141.1           23.8
#       M           731.4          587.4         144.0           24.5
# total             704.6          602.2         102.4           17.0
#          non_eth2001 (emis)  non_eth2001 (tpp)  diff (e - t)  diff (% of t)
# 16-39 F               247.1              352.9        -105.8          -30.0
#       M               218.0              309.0         -91.0          -29.4
# 40-69 F               317.8              390.8         -73.0          -18.7
#       M               290.9              368.2         -77.3          -21.0
# 70+   F               327.9              380.1         -52.2          -13.7
#       M               325.2              379.7         -54.5          -14.4
# total                 280.0              361.4         -81.4          -22.5
#          eth_norecord (emis)  eth_norecord (tpp)  diff (e - t)  diff (% of t)
# 16-39 F                  5.2                 5.8          -0.6          -10.3
#       M                  5.4                 5.6          -0.2           -3.6
# 40-69 F                  6.0                 6.1          -0.1           -1.6
#       M                  6.3                 6.0           0.3            5.0
# 70+   F                  5.7                 5.7           0.0            0.0
#       M                  5.6                 5.2           0.4            7.7
# total                    5.7                 5.8          -0.1           -1.7
#          eth_notgiptref (emis)  eth_notgiptref (tpp)  diff (e - t)  \
# 16-39 F                    0.0                   0.0           0.0
#       M                    0.0                   0.0           0.0
# 40-69 F                    0.0                   0.0           0.0
#       M                    0.0                   0.0           0.0
# 70+   F                    0.0                   0.0           0.0
#       M                    0.0                   0.0           0.0
# total                      0.0                   0.0           0.0
#
#          diff (% of t)
# 16-39 F            0.0
#       M            0.0
# 40-69 F            0.0
#       M            0.0
# 70+   F            0.0
#       M            0.0
# total              0.0
#          eth_notstated (emis)  eth_notstated (tpp)  diff (e - t)  \
# 16-39 F                  31.4                 45.3         -13.9
#       M                  29.7                 46.6         -16.9
# 40-69 F                  19.8                 48.4         -28.6
#       M                  20.7                 49.6         -28.9
# 70+   F                  16.0                 49.5         -33.5
#       M                  15.6                 49.4         -33.8
# total                    23.5                 47.9         -24.4
#
#          diff (% of t)
# 16-39 F          -30.7
#       M          -36.3
# 40-69 F          -59.1
#       M          -58.3
# 70+   F          -67.7
#       M          -68.4
# total            -50.9
# ##
#  ## Care home resident
#          longres (emis)  longres (tpp)  diff (e - t)  diff (% of t)
# 16-39 F             0.6            0.9          -0.3          -33.3
#       M             1.0            1.6          -0.6          -37.5
# 40-69 F             2.1            2.5          -0.4          -16.0
#       M             2.7            3.3          -0.6          -18.2
# 70+   F            43.5           49.9          -6.4          -12.8
#       M            23.0           26.4          -3.4          -12.9
# total               6.9            8.6          -1.7          -19.8
# ##
#  ## Care staff
#          carehome (emis)  carehome (tpp)  diff (e - t)  diff (% of t)
# 16-39 F              0.3             0.9          -0.6          -66.7
#       M              0.1             0.1           0.0            0.0
# 40-69 F              0.6             1.4          -0.8          -57.1
#       M              0.1             0.2          -0.1          -50.0
# 70+   F              0.2             0.2           0.0            0.0
#       M              0.0             0.1          -0.1         -100.0
# total                0.3             0.6          -0.3          -50.0
#          nursehome (emis)  nursehome (tpp)  diff (e - t)  diff (% of t)
# 16-39 F               0.1              0.2          -0.1          -50.0
#       M               0.0              0.0           0.0            0.0
# 40-69 F               0.1              0.3          -0.2          -66.7
#       M               0.0              0.0           0.0            0.0
# 70+   F               0.0              0.0           0.0            0.0
#       M               0.0              0.0           0.0            0.0
# total                 0.0              0.1          -0.1         -100.0
#          domcare (emis)  domcare (tpp)  diff (e - t)  diff (% of t)
# 16-39 F             0.2            0.6          -0.4          -66.7
#       M             0.0            0.1          -0.1         -100.0
# 40-69 F             0.5            1.4          -0.9          -64.3
#       M             0.1            0.3          -0.2          -66.7
# 70+   F             0.0            0.1          -0.1         -100.0
#       M             0.0            0.1          -0.1         -100.0
# total               0.2            0.5          -0.3          -60.0
# ##
#  ## Carer / household
#          carer (emis)  carer (tpp)  diff (e - t)  diff (% of t)
# 16-39 F          21.6         16.4           5.2           31.7
#       M           8.9          6.7           2.2           32.8
# 40-69 F          67.7         60.6           7.1           11.7
#       M          28.0         25.0           3.0           12.0
# 70+   F          84.0         84.3          -0.3           -0.4
#       M          57.5         57.3           0.2            0.3
# total            38.9         36.1           2.8            7.8
#          notcarer (emis)  notcarer (tpp)  diff (e - t)  diff (% of t)
# 16-39 F             48.3            16.8          31.5          187.5
#       M             32.4            11.6          20.8          179.3
# 40-69 F             47.6            19.5          28.1          144.1
#       M             39.7            14.3          25.4          177.6
# 70+   F             61.3            33.6          27.7           82.4
#       M             53.1            23.6          29.5          125.0
# total               44.6            18.0          26.6          147.8
#          hhld_imdef (emis)  hhld_imdef (tpp)  diff (e - t)  diff (% of t)
# 16-39 F                0.2               0.5          -0.3          -60.0
#       M                0.2               0.5          -0.3          -60.0
# 40-69 F                0.3               0.7          -0.4          -57.1
#       M                0.2               0.6          -0.4          -66.7
# 70+   F                0.1               0.2          -0.1          -50.0
#       M                0.1               0.2          -0.1          -50.0
# total                  0.2               0.5          -0.3          -60.0
# ##
#  ## Shielding
#          shield (emis)  shield (tpp)  diff (e - t)  diff (% of t)
# 16-39 F           34.3          37.2          -2.9           -7.8
#       M           18.6          20.4          -1.8           -8.8
# 40-69 F           81.4          83.1          -1.7           -2.0
#       M           66.9          69.3          -2.4           -3.5
# 70+   F          181.2         195.5         -14.3           -7.3
#       M          243.7         258.7         -15.0           -5.8
# total             77.5          84.4          -6.9           -8.2
#          nonshield (emis)  nonshield (tpp)  diff (e - t)  diff (% of t)
# 16-39 F              12.2             21.1          -8.9          -42.2
#       M               8.5             11.9          -3.4          -28.6
# 40-69 F              19.2             33.4         -14.2          -42.5
#       M              15.2             28.3         -13.1          -46.3
# 70+   F              30.2             55.8         -25.6          -45.9
#       M              30.4             57.9         -27.5          -47.5
# total                16.7             30.0         -13.3          -44.3
# ##
#  ## Asthma
#          ast (emis)  ast (tpp)  diff (e - t)  diff (% of t)
# 16-39 F       146.0      156.0         -10.0           -6.4
#       M       160.5      167.4          -6.9           -4.1
# 40-69 F       150.5      153.3          -2.8           -1.8
#       M       119.6      121.7          -2.1           -1.7
# 70+   F       141.5      134.7           6.8            5.0
#       M       109.2      104.6           4.6            4.4
# total         140.7      143.5          -2.8           -2.0
#          astadm (emis)  astadm (tpp)  diff (e - t)  diff (% of t)
# 16-39 F            6.1           4.1           2.0           48.8
#       M            5.4           4.9           0.5           10.2
# 40-69 F            7.2           4.9           2.3           46.9
#       M            3.9           3.1           0.8           25.8
# 70+   F            6.1           4.8           1.3           27.1
#       M            4.1           3.2           0.9           28.1
# total              5.5           4.2           1.3           31.0
#          astrx (emis)  astrx (tpp)  diff (e - t)  diff (% of t)
# 16-39 F          99.1        102.0          -2.9           -2.8
#       M          86.1         77.9           8.2           10.5
# 40-69 F         199.9        214.6         -14.7           -6.8
#       M         132.0        143.0         -11.0           -7.7
# 70+   F         309.4        318.0          -8.6           -2.7
#       M         264.9        273.0          -8.1           -3.0
# total           157.3        166.2          -8.9           -5.4
# ##
#  ## BMI
#          bmi (emis)  bmi (tpp)  diff (e - t)  diff (% of t)
# 16-39 F       813.5      845.2         -31.7           -3.8
#       M       625.1      653.4         -28.3           -4.3
# 40-69 F       945.3      954.1          -8.8           -0.9
#       M       886.7      895.1          -8.4           -0.9
# 70+   F       959.8      970.0         -10.2           -1.1
#       M       958.4      966.1          -7.7           -0.8
# total         846.3      866.5         -20.2           -2.3
#          bmi_stage (emis)  bmi_stage (tpp)  diff (e - t)  diff (% of t)
# 16-39 F              49.0             63.1         -14.1          -22.3
#       M              27.7             35.7          -8.0          -22.4
# 40-69 F             140.0            185.4         -45.4          -24.5
#       M             103.5            148.8         -45.3          -30.4
# 70+   F             165.6            221.7         -56.1          -25.3
#       M             158.6            221.0         -62.4          -28.2
# total                95.9            132.7         -36.8          -27.7
#          sev_obesity (emis)  sev_obesity (tpp)  diff (e - t)  diff (% of t)
# 16-39 F                 4.6                5.7          -1.1          -19.3
#       M                 1.5                1.8          -0.3          -16.7
# 40-69 F                11.9               14.5          -2.6          -17.9
#       M                 5.5                7.2          -1.7          -23.6
# 70+   F                 8.0                9.4          -1.4          -14.9
#       M                 4.9                5.9          -1.0          -16.9
# total                   6.1                7.7          -1.6          -20.8
# ##
#  ## CKD
#          ckd15 (emis)  ckd15 (tpp)  diff (e - t)  diff (% of t)
# 16-39 F           1.8          2.0          -0.2          -10.0
#       M           1.6          1.6           0.0            0.0
# 40-69 F          28.1         27.6           0.5            1.8
#       M          23.5         22.4           1.1            4.9
# 70+   F         235.2        233.1           2.1            0.9
#       M         202.8        198.1           4.7            2.4
# total            48.0         50.0          -2.0           -4.0
#          ckd35 (emis)  ckd35 (tpp)  diff (e - t)  diff (% of t)
# 16-39 F           0.8          0.8           0.0            0.0
#       M           0.8          0.7           0.1           14.3
# 40-69 F          21.9         21.1           0.8            3.8
#       M          17.6         16.2           1.4            8.6
# 70+   F         222.0        219.7           2.3            1.0
#       M         187.7        182.6           5.1            2.8
# total            42.7         44.2          -1.5           -3.4
#          ckd_cov (emis)  ckd_cov (tpp)  diff (e - t)  diff (% of t)
# 16-39 F             1.4            1.5          -0.1           -6.7
#       M             1.8            1.8           0.0            0.0
# 40-69 F             4.0            3.8           0.2            5.3
#       M             4.9            4.7           0.2            4.3
# 70+   F            14.0           13.0           1.0            7.7
#       M            16.5           15.0           1.5           10.0
# total               5.1            5.0           0.1            2.0
# ##
#  ## Immunodeficiency
#          immdx_cov (emis)  immdx_cov (tpp)  diff (e - t)  diff (% of t)
# 16-39 F               4.2              4.4          -0.2           -4.5
#       M               4.6              4.6           0.0            0.0
# 40-69 F              13.1             13.0           0.1            0.8
#       M              14.1             13.3           0.8            6.0
# 70+   F              26.6             27.0          -0.4           -1.5
#       M              32.6             32.6           0.0            0.0
# total                12.6             12.8          -0.2           -1.6
#          immrx (emis)  immrx (tpp)  diff (e - t)  diff (% of t)
# 16-39 F           8.5          7.9           0.6            7.6
#       M           7.1          6.2           0.9           14.5
# 40-69 F          25.9         24.6           1.3            5.3
#       M          17.8         16.5           1.3            7.9
# 70+   F          37.9         35.7           2.2            6.2
#       M          30.1         27.6           2.5            9.1
# total            18.4         17.5           0.9            5.1
# ##
#  ## Diabetes
#          diab (emis)  diab (tpp)  diff (e - t)  diff (% of t)
# 16-39 F         26.7        28.1          -1.4           -5.0
#       M         10.5        11.2          -0.7           -6.2
# 40-69 F         82.6        81.2           1.4            1.7
#       M         98.3        98.8          -0.5           -0.5
# 70+   F        167.1       164.8           2.3            1.4
#       M        225.2       223.5           1.7            0.8
# total           79.4        81.6          -2.2           -2.7
#          dmres (emis)  dmres (tpp)  diff (e - t)  diff (% of t)
# 16-39 F           0.3          0.5          -0.2          -40.0
#       M           0.1          0.2          -0.1          -50.0
# 40-69 F           1.6          2.1          -0.5          -23.8
#       M           1.8          1.8           0.0            0.0
# 70+   F           4.9          5.1          -0.2           -3.9
#       M           6.0          6.0           0.0            0.0
# total             1.7          2.0          -0.3          -15.0
# ##
#  ##  Heart/lung conditions
#          chd_cov (emis)  chd_cov (tpp)  diff (e - t)  diff (% of t)
# 16-39 F            11.1           12.5          -1.4          -11.2
#       M             8.3            9.0          -0.7           -7.8
# 40-69 F            62.3           63.6          -1.3           -2.0
#       M            87.1           91.8          -4.7           -5.1
# 70+   F           284.5          285.8          -1.3           -0.5
#       M           386.7          390.2          -3.5           -0.9
# total              91.2           97.6          -6.4           -6.6
#          resp_cov (emis)  resp_cov (tpp)  diff (e - t)  diff (% of t)
# 16-39 F              2.5             2.5           0.0            0.0
#       M              2.6             2.7          -0.1           -3.7
# 40-69 F             28.1            29.2          -1.1           -3.8
#       M             27.6            28.5          -0.9           -3.2
# 70+   F             99.3            98.2           1.1            1.1
#       M            123.0           123.5          -0.5           -0.4
# total               31.4            33.2          -1.8           -5.4
#          cld (emis)  cld (tpp)  diff (e - t)  diff (% of t)
# 16-39 F         5.2        5.7          -0.5           -8.8
#       M         6.9        8.0          -1.1          -13.7
# 40-69 F        23.8       25.1          -1.3           -5.2
#       M        29.7       31.3          -1.6           -5.1
# 70+   F        23.5       24.4          -0.9           -3.7
#       M        27.2       26.8           0.4            1.5
# total          18.5       19.8          -1.3           -6.6
# ##
#  ## Other conditions
#          cns_cov (emis)  cns_cov (tpp)  diff (e - t)  diff (% of t)
# 16-39 F            17.8           19.0          -1.2           -6.3
#       M            19.2           20.0          -0.8           -4.0
# 40-69 F            39.2           40.6          -1.4           -3.4
#       M            39.3           41.5          -2.2           -5.3
# 70+   F           132.9          140.8          -7.9           -5.6
#       M           142.2          148.0          -5.8           -3.9
# total              47.1           51.1          -4.0           -7.8
#          spln_cov (emis)  spln_cov (tpp)  diff (e - t)  diff (% of t)
# 16-39 F              5.2             5.8          -0.6          -10.3
#       M              2.7             2.8          -0.1           -3.6
# 40-69 F              7.4             8.0          -0.6           -7.5
#       M              4.8             5.1          -0.3           -5.9
# 70+   F              8.8             9.3          -0.5           -5.4
#       M              7.3             7.7          -0.4           -5.2
# total                5.6             6.1          -0.5           -8.2
# ##
#  ## MH / LD
#          sev_mental (emis)  sev_mental (tpp)  diff (e - t)  diff (% of t)
# 16-39 F                7.2               7.3          -0.1           -1.4
#       M                9.3               9.0           0.3            3.3
# 40-69 F               15.0              14.7           0.3            2.0
#       M               16.0              15.4           0.6            3.9
# 70+   F               14.8              13.6           1.2            8.8
#       M               10.3               9.6           0.7            7.3
# total                 12.3              11.9           0.4            3.4
#          smhres (emis)  smhres (tpp)  diff (e - t)  diff (% of t)
# 16-39 F            0.7           1.3          -0.6          -46.2
#       M            0.8           1.6          -0.8          -50.0
# 40-69 F            2.0           3.9          -1.9          -48.7
#       M            2.1           4.1          -2.0          -48.8
# 70+   F            2.2           4.4          -2.2          -50.0
#       M            1.7           3.3          -1.6          -48.5
# total              1.5           3.0          -1.5          -50.0
#          learndis (emis)  learndis (tpp)  diff (e - t)  diff (% of t)
# 16-39 F              5.4             6.5          -1.1          -16.9
#       M              9.4            10.8          -1.4          -13.0
# 40-69 F              4.3             4.7          -0.4           -8.5
#       M              5.5             6.0          -0.5           -8.3
# 70+   F              1.8             1.7           0.1            5.9
#       M              2.4             2.2           0.2            9.1
# total                5.4             6.0          -0.6          -10.0
# ##
#  ## Pregnancy/delivery
#          preg (emis)  preg (tpp)  diff (e - t)  diff (% of t)
# 16-39 F         81.3        76.8           4.5            5.9
#       M          1.7         0.2           1.5          750.0
# 40-69 F          6.5         4.6           1.9           41.3
#       M          0.5         0.2           0.3          150.0
# 70+   F          1.3         0.4           0.9          225.0
#       M          1.5         0.3           1.2          400.0
# total           17.7        15.3           2.4           15.7
#          pregdel (emis)  pregdel (tpp)  diff (e - t)  diff (% of t)
# 16-39 F            99.6           99.4           0.2            0.2
#       M             0.9            0.2           0.7          350.0
# 40-69 F             8.3            6.3           2.0           31.7
#       M             0.3            0.3           0.0            0.0
# 70+   F             0.7            0.5           0.2           40.0
#       M             0.8            0.4           0.4          100.0
# total              21.3           19.9           1.4            7.0
# ##
#  ## Covid vax
#          cov1decl (emis)  cov1decl (tpp)  diff (e - t)  diff (% of t)
# 16-39 F              0.0             3.6          -3.6         -100.0
#       M              0.0             2.5          -2.5         -100.0
# 40-69 F              0.0             7.7          -7.7         -100.0
#       M              0.0             7.0          -7.0         -100.0
# 70+   F              0.0            23.8         -23.8         -100.0
#       M              0.0            19.8         -19.8         -100.0
# total                0.0             8.3          -8.3         -100.0
#          cov2decl (emis)  cov2decl (tpp)  diff (e - t)  diff (% of t)
# 16-39 F              0.0             2.5          -2.5         -100.0
#       M              0.0             1.7          -1.7         -100.0
# 40-69 F              0.0             5.3          -5.3         -100.0
#       M              0.0             4.9          -4.9         -100.0
# 70+   F              0.0            17.8         -17.8         -100.0
#       M              0.0            14.6         -14.6         -100.0
# total                0.0             5.9          -5.9         -100.0
#          covadm1 (emis)  covadm1 (tpp)  diff (e - t)  diff (% of t)
# 16-39 F             0.0          170.0        -170.0         -100.0
#       M             0.0           82.7         -82.7         -100.0
# 40-69 F             0.0          480.1        -480.1         -100.0
#       M             0.0          369.6        -369.6         -100.0
# 70+   F             0.0          889.5        -889.5         -100.0
#       M             0.0          881.2        -881.2         -100.0
# total               0.0          393.9        -393.9         -100.0
#          covadm2 (emis)  covadm2 (tpp)  diff (e - t)  diff (% of t)
# 16-39 F             0.0          170.1        -170.1         -100.0
#       M             0.0           82.7         -82.7         -100.0
# 40-69 F             0.0          480.3        -480.3         -100.0
#       M             0.0          369.7        -369.7         -100.0
# 70+   F             0.0          890.0        -890.0         -100.0
#       M             0.0          881.7        -881.7         -100.0
# total               0.0          394.1        -394.1         -100.0
#          covcontra (emis)  covcontra (tpp)  diff (e - t)  diff (% of t)
# 16-39 F               0.0              0.0           0.0            0.0
#       M               0.0              0.0           0.0            0.0
# 40-69 F               0.0              0.0           0.0            0.0
#       M               0.0              0.0           0.0            0.0
# 70+   F               0.0              0.0           0.0            0.0
#       M               0.0              0.0           0.0            0.0
# total                 0.0              0.0           0.0            0.0
#          covrx (emis)  covrx (tpp)  diff (e - t)  diff (% of t)
# 16-39 F         157.2        170.2         -13.0           -7.6
#       M          82.9         82.8           0.1            0.1
# 40-69 F         486.2        480.3           5.9            1.2
#       M         384.2        369.8          14.4            3.9
# 70+   F         861.8        890.1         -28.3           -3.2
#       M         854.5        881.7         -27.2           -3.1
# total           381.3        394.1         -12.8           -3.2
